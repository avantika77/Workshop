# %% [markdown]
# # https://bit.ly/jnuworkshop

# %%
import pandas

# %%
pandas.Series(["AB","CD","EF"])
# Out:
# 0    AB
# 1    CD
# 2    EF
# dtype: object

# %%
pandas.Series([10,20,30,"tushar"])
# Out:
# 0        10
# 1        20
# 2        30
# 3    tushar
# dtype: object

# %%
# giving alias name to the pandas ( nickname)

# %%
import pandas as pd

# %%
pd.Series([10,20,30], index=["a","B","c"])
# Out:
# a    10
# B    20
# c    30
# dtype: int64

# %%
seriesData = pd.Series({"A":10,
           "B":20},index=["100","200"])
seriesData
# Out:
# 100   NaN
# 200   NaN
# dtype: float64

# %% [markdown]
# Assing this column data we call series to a variable

# %%
seriesdata=pd.Series({"Product A":100,
           "Product B":20,
            "Product C":30    })
seriesdata
# Out:
# Product A    100
# Product B     20
# Product C     30
# dtype: int64

# %%
# checking data type

seriesdata.dtype
# Out:
# dtype('int64')

# %%
seriesdata.min()
# Out:
# 20

# %%
# checking the index

seriesdata.index
# Out:
# Index(['Product A', 'Product B', 'Product C'], dtype='object')

# %%
seriesdata
# Out:
# Product A    100
# Product B     20
# Product C     30
# dtype: int64

# %%
# it gives you total number of element
len(seriesdata )
# Out:
# 3

# %%
# tells what type of value you hold
type(seriesdata)
# Out:
# pandas.core.series.Series

# %%
seriesdata
# Out:
# Product A    100
# Product B     20
# Product C     30
# dtype: int64

# %%
# gives you the data in form of dictionary
dict(seriesdata)
# Out:
# {'Product A': 100, 'Product B': 20, 'Product C': 30}

# %%
# sort the data completely in ascending order
sorted(seriesdata)
# Out:
# [20, 30, 100]

# %%
# give the column data in form of list
list(seriesdata)
# Out:
# [100, 20, 30]

# %%
seriesdata
# Out:
# Product A    100
# Product B     20
# Product C     30
# dtype: int64

# %%
seriesdata.max()
# Out:
# 100

# %%
# gives you max value from the series data
max(seriesdata)
# Out:
# 100

# %%
# it gives the max value again - no difference in both function
seriesdata.max()
# Out:
# 100

# %%
seriesdata
# Out:
# Product A    100
# Product B     20
# Product C     30
# dtype: int64

# %%
seriesdata.idxmin()
# Out:
# 'Product B'

# %%
# return the index of the maximum value here
seriesdata.idxmax()
# Out:
# 'Product A'

# %%
seriesdata[ ["Product A","Product B"] ]
# Out:
# Product A    99
# Product B    20
# dtype: int64

# %%
seriesdata
# Out:
# Product A    99
# Product B    20
# Product C    30
# dtype: int64

# %%
seriesdata
# Out:
# Product A    99
# Product B    20
# Product C    30
# dtype: int64

# %%
# sort the complete series here in ascending order
seriesdata.sort_values(ascending=False)
# Out:
# Product A    99
# Product C    30
# Product B    20
# dtype: int64

# %%
# sort the complete series here in ascending order
seriesdata.sort_values(ascending=False)
# Out:
# Product A    100
# Product C     30
# Product B     20
# dtype: int64

# %%
# updating 1 values
seriesdata["Product A"]=200

# %%
seriesdata
# Out:
# Product A    200
# Product B     20
# Product C     30
# dtype: int64

# %%
# checking do we have any index in the series index
"Product A" in seriesdata
# Out:
# True

# %%
# checking the value exist in series data or not

200 in seriesdata.values
# Out:
# True

# %%
seriesdata
# Out:
# Product A    200
# Product B     20
# Product C     30
# dtype: int64

# %%
# selecting 1 data based on index
seriesdata["Product A"]
# Out:
# 200

# %%
#selecting multiple data
seriesdata[ [ "Product A", "Product C"]]
# Out:
# Product A    200
# Product C     30
# dtype: int64

# %%
# selecting range of data
seriesdata[ "Product A" : "Product C"]
# Out:
# Product A    200
# Product B     20
# Product C     30
# dtype: int64

# %% [markdown]
# # DataFrame is collection of data in tabular like structure containing data in rows and columns
# ## How to create dataframe

# %%
# creating dataframe with series
numberSeries = pd.Series([10,20,30])
nameSeries =  pd.Series(["Virat","Hardik","Rohit"])

# %%
nameSeries

pd.DataFrame([numberSeries, nameSeries])
# Out:
#        0       1      2
# 0     10      20     30
# 1  Virat  Hardik  Rohit

# %%
import pandas as pd
numberSeries = pd.Series([10,20,30])
nameSeries =  pd.Series(["Virat","Hardik","Rohit"])

pd.DataFrame([numberSeries,nameSeries])
# Out:
#        0       1      2
# 0     10      20     30
# 1  Virat  Hardik  Rohit

# %%
df=pd.DataFrame({"rollNo":numberSeries,"Name":nameSeries})

# %%
df.head(2)
# Out:
#    rollNo    Name
# 0      10   Virat
# 1      20  Hardik

# %%
df.tail(2)
# Out:
#    rollNo    Name
# 1      20  Hardik
# 2      30   Rohit

# %%
df["Name"]

type( df["Name"] )
# Out:
# pandas.core.series.Series

# %%
# assinging to a dataframe - df variable
df=pd.DataFrame({"rollNo":numberSeries,"Name":nameSeries})

# %%
df
# Out:
#    rollNo     Name
# 0      10    Virat
# 1      20   Hardik
# 2      30  Vadapav

# %%
# selecting 1 column here
df["rollNo"]
# Out:
# 0    10
# 1    20
# 2    30
# Name: rollNo, dtype: int64

# %% [markdown]
# # Creating Dataframe from an exisiting file
#
# ### In google colab you need to upload the file from the local system

# %% [markdown]
# ### Download the NbaInfo.csv file from here
#
# #### https://bit.ly/jnudata

# %%
# upload the file here

from google.colab import files

uploaded = files.upload()
# select the choose files option and select and upload file here
# NbaInfo.csv file needs to be uploaded here
# Out:
#      <input type="file" id="files-800599ac-03eb-4472-9801-d58940093899" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-800599ac-03eb-4472-9801-d58940093899">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### *Creating dataframe here with the csv file in Pandas*

# %%
import pandas as pd
import io

# replace the NbaInfo file in case of creating dataframe with other file

df = pd.read_csv(io.BytesIO(uploaded['NbaInfo.csv']))
print(df)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...
